# %% [markdown]
# <a href="https://colab.research.google.com/github/RNikhitha/NLP/blob/main/NLP_Handson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 1 STEMMING

# %% [markdown]
# ALL EXCEPTIONS

# %%
import nltk 
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('loving')
# Out:
# 'love'

# %%
from nltk.stem import LancasterStemmer
stemmerLan = LancasterStemmer()
stemmerLan.stem('loving')
# Out:
# 'lov'

# %%
from nltk.stem import SnowballStemmer
SnowballStemmer.languages 
frenchstemmer=SnowballStemmer('french')
frenchstemmer.stem('manges')
# Out:
# 'mang'

# %%
from nltk.stem import RegexpStemmer
stemmerregexp = RegexpStemmer('ing')
stemmerregexp.stem('singing')
# Out:
# 's'

# %% [markdown]
# TASK 2 - STEM A PARAGRAPH

# %%
from nltk.stem import PorterStemmer 
stemmer = PorterStemmer()
text = ''
text = [stemmer.stem(token) for token in text.split(" ")]
print(" ".join(text))
# Out:
# sometim call state control, is a neuro-linguist program (nlp) techniqu involv activ tri to control the emot and mental state of an individual.

# %%
with open('text.txt', 'r') as f:
        for line in f:
            tokens = []
            stemmer = PorterStemmer() 
            for plural in line.split():
                tokens.append(stemmer.stem(plural))
            print(' '.join(tokens))
# Out:
# ﻿natur languag process (nlp) refer to the branch of comput science—and more specifically, the branch of artifici intellig or ai—concern with give comput the abil to understand text and spoken word in much the same way human be can.
# nlp combin comput linguistics—rule-bas model of human language—with statistical, machin learning, and deep learn models. together, these technolog enabl comput to process human languag in the form of text or voic data and to ‘understand’ it full meaning, complet with the speaker or writer’ intent and sentiment.
# ...

# %% [markdown]
# TASK 3 - LEMMATIZER

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("formulae"))
# Out:
# cactus
# formula

# %%
print(lemmatizer.lemmatize("better",pos='a'))
# Out:
# good

# %%
print(lemmatizer.lemmatize("am",pos='v'))
# Out:
# be

# %% [markdown]
# TASK 4 - Chinese Segmentation

# %%
import jieba
seg = jieba.cut("每个人都有他的作战策略，直到脸上中了一拳。")
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 1.029 seconds.
# DEBUG:jieba:Loading model cost 1.029 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# 每个 人 都 有 他 的 作战 策略 ， 直到 脸上 中 了 一拳 。

# %% [markdown]
# Task 5 -

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
texts = "Natural language processing (NLP) refers to the branch of computer science—and more specifically, the branch of artificial intelligence or AI—concerned with giving computers the ability to understand text and spoken words in much the same way human beings can."
for text in texts:
  sentences =nltk.sent_tokenize(texts)
  for sentence in sentences:
    word = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(word)
    print(tagged)
# Out:
# [('Natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('(', '('), ('NLP', 'NNP'), (')', ')'), ('refers', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('branch', 'NN'), ('of', 'IN'), ('computer', 'NN'), ('science—and', 'NN'), ('more', 'RBR'), ('specifically', 'RB'), (',', ','), ('the', 'DT'), ('branch', 'NN'), ('of', 'IN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('or', 'CC'), ('AI—concerned', 'VBN'), ('with', 'IN'), ('giving', 'VBG'), ('computers', 'NNS'), ('the', 'DT'), ('ability', 'NN'), ('to', 'TO'), ('understand', 'VB'), ('text', 'NN'), ('and', 'CC'), ('spoken', 'JJ'), ('words', 'NNS'), ('in', 'IN'), ('much', 'JJ'), ('the', 'DT'), ('same', 'JJ'), ('way', 'NN'), ('human', 'JJ'), ('beings', 'NNS'), ('can', 'MD'), ('.', '.')]
# ...
